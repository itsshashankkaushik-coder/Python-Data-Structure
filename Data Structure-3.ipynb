# %% [raw]
#                             DATA TYPES AND STRUCTURES QUESTION

# %% [raw]
# 1.What are data structures, and why are they important?
# - Data structures are the ways of organising, storing and managing the data in a computer so it can easily get accessed and updated effeciently.

# %% [raw]
# 2.Explain the difference between mutable and immutable data types with examples.
# - Mutable data type - data can be changed when it is created (eg.list)
# - Immutabel data type - Data can not be changed when it is created (eg.Tuple)

# %% [raw]
# 3.What are the main difference between lists and tuples in python?
# - The main difference in between the list and the tuples is theri mutability lists can be mutable and tuples are immutable.

# %% [raw]
# 4.Describe how dictonaries store data.
# - In dictionaries data stored as key-value pairs.They use a hash type of data functionality to store data accordingly.

# %% [raw]
# 5.Why might you use a set instead of a list in python?
# - In set we can store only unique data but list can store the duplicate data too
# - Built-in functions also helpful in set to specify the data in set but in list these operations must be coded manually.

# %% [raw]
# 6.What is a string in python, and how is it different from a list?
# - String can store characteres but list can store every data type in it.
# - String are immutable and list are mutable in the python.

# %% [raw]
# 7.How do tuples ensure data integrity in python?
# - Tuples ensures the data integrity with the immutability in it and it seprates tuple from the other data types in the python.

# %% [raw]
# 8.What is a hash table, and how does it relate to dictionaries in python?
# - A hash table is a data structure that stores key-value pairs by using a hash function to compute an index, or "a bucket"
# - In Python (dict) dictionary is implemented using a hash table. The keys stored in the in the hash values and make it easier to access it.

# %% [raw]
# 9.Can lists contain different data types in python?
# - Yes lists can contain different data types in the python (eg.integers, strings, floats, etc.)

# %% [raw]
# 10.Explain why strings are immutable in python?
# - Strings are immutable because once a string is created it cannot be changed. As we can use concatenation and replacement to actually create a new string object in the memory. These functions can make strings suitable to use it for the dictionary keys and elements in the sets.

# %% [raw]
# 11.What advantages do dictonaries offer over lists for certain tasks?
# - Dictionaries offer a major speed advantage for tasks that fast lookups, insertions and deletions using a key but in the list there is a time complexity for searching a value.They are best for storing key-value.

# %% [raw]
# 12.Describe a scenario where using a tuple would be preferable over a list.
# - Tuple mainly useful for storing which were certain over there and want as they stored as like coordinates of the numbeer line and emoloyee id's of the employees.In these type of conditions tuple is preferable rather than the list.

# %% [raw]
# 13.How do sets handle duplicate values in Python?
# - A python set automatically discard the duplicate values by themselves in the python.

# %% [raw]
# 14.How does the "in" keyword work differntly for lists and dictionaries?
# - For a list in checks the value of an element is present among the values
#   eg.- 3 in [1,2,3] #true
# - For a dictionary in checks if an element is present among the keys.
#   eg.- a in {'a': 1, 'b': 2} #True
#        1 in {'a': 1, 'b': 2} #False
# (checks the keys, not values)

# %% [raw]
# 15.Can you modify the elements of a tuple? Explain why or why not.
# - No you cannot modify the elements of a tuple
# tuple are immutable (their content can't be changed after they created). Any attempt to change will lead to the TypeError.

# %% [raw]
# 16.What is a nested dictionary, and give an example of its use case?
# - Nested dictionary is a dictionary where the value of a key is another dictionary.

# %% [raw]
# 17.Describe the time complexity of accessing elements in a dictionary.
# - Accessing elements  in a dictinary (lookup by key) has an average time complexity (constant time).

# %% [raw]
# 18.In what situations lists preferred over dictioaries?
# - You should prefer list over dictonaries when we wnat to have the duplicate values and when you need an ordered collection of items,need to access elements by their index numbers.

# %% [raw]
# 19.Why are dictionaries considered unordered, and how does that affect data retrieval?
# - In the python (version 3.7+) dictionaries are considered ordered because they maintain insertion order keys are retrieved in the sequence they were added.This order does not affect the speed of the data retrieval by the key.

# %% [raw]
# 20.Explain the difference between a list and a dictionary in terms of data retrieval.
# - A list stores data as an sequence order, where each item is accessed by its integer index (position). Data retrieval speed is depend on the location.
# - A dictionary stores data as an unordered (key-value pairs) where each value is accessed by its hashable object. Data retrieval by key is consistently very fast.

# %% [raw]
#                                 PRACTICAL QUESTIONS

# %%
#1.Write a code to create a string with your name and print it.
x="Shashank"
print(x)
# Out:
# Shashank

# %%
#2.Write a code to find the length of the string "Hello World".
x="Hello World"
len(x)
# Out:
# 11

# %%
#3.Write a code to slice the first 3 characters from the string "Python Programming".
x="Python Programming"
print(x[0:3])
# Out:
# Pyt

# %%
#4.Write a code to convert the string "hello" to uppercase
x="Hello"
print(x.upper())
# Out:
# HELLO

# %%
#5.Write a code to replace the word "apple" with "orange" in the string "i like apple".
x="i like apple"
y=x.replace("apple","orange")
print(y)
# Out:
# i like orange

# %%
#6.Write a code to create a list with numbers 1 to 5 and print it.
list_name=[1,2,3,4,5]
print(list_name)
# Out:
# [1, 2, 3, 4, 5]

# %%
#7.Write a code to append the number 10 to the list [1,2,3,4]
new_list=[1,2,3,4]
new_list.append(10)
print(new_list)
# Out:
# [1, 2, 3, 4, 10]

# %%
#8.Write a code to remove a number 3 from the list[1,2,3,4,5]
second_list=[1,2,3,4,5]
second_list.remove(3)
print(second_list)
# Out:
# [1, 2, 4, 5]

# %%
#9.Write a code to access the second element in the list['a','b','c','d'].
alpha_list=['a','b','c','d']
print(alpha_list[1])
# Out:
# b

# %%
#10.Write a code to reverse the list[10,20,30,40,50].
num_list=[10,20,30,40,50]
print(num_list[::-1])
# Out:
# [50, 40, 30, 20, 10]

# %%
#11.Write a code to create a tuple with the elements 100,200,300 and print it.
something=(100,200,300)
print (type(something),something)
# Out:
# <class 'tuple'> (100, 200, 300)

# %%
#12.Write a code to access the second-to-last element of the tuple('red','green','blue','yellow')
fruits_tuple=('red','green','blue','yellow')
print(fruits_tuple[-2])
# Out:
# blue

# %%
#13.Write a code to find the minimum number in the tuple(10,20,5,15)
number_list=(10,20,5,15)
print(min(number_list))
# Out:
# 5

# %%
#14.Write a code to find the index of the element "cat" in the tuple ('dog','cat','rabbit').
animals_list=('dog','cat','rabbit')
print(animals_list.index('cat'))
# Out:
# 1

# %%
#15.Write a code to create a tuple containing three different fruits and check if "kiwi" is in it.
new_fruits=("Banana","Pineapple","kiwi","Blackberry")
print("kiwi" in new_fruits)
# Out:
# True

# %%
#16.Write a code to create a set with the elements 'a','b','c' and print it.
new_set={'a','b','c'}
print(new_set)
# Out:
# {'b', 'c', 'a'}

# %%
#17.Write a code to clear all elements from the set{1,2,3,4,5}
limit_set={1,2,3,4,5}
print(limit_set.clear(),limit_set)
# Out:
# None set()

# %%
#18.Write a code to remove the elements 4 from the set {1,2,3,4}
few_set={1,2,3,4}
few_set.remove(4)
print(few_set)
# Out:
# {1, 2, 3}

# %%
#19.Write a code to find the union of two sets{1,2,3} and {3,4,5}
a={1,2,3}
b={3,4,5}
print(a|b)
# Out:
# {1, 2, 3, 4, 5}

# %%
#20.Write a code to find the intersection of two sets {1,2,3} and {2,3,4}.
a= {1,2,3} 
b= {2,3,4} 
print(a&b)
# Out:
# {2, 3}

# %%
#21.Write a code to create a dictionary with the keys "name","age" and "city" and print it.
Demographics={"name":"Jack", "age":20, "city":"Ranchi"}
print(Demographics)
# Out:
# {'name': 'Jack', 'age': 20, 'city': 'Ranchi'}

# %%
#22.Write a code to add a new key_value pair "country":"USA" to the dictionary{'name':'John','age':25}.
Alice={'name':'Alice','age':30}
Alice["country"]="USA"
print(Alice)
# Out:
# {'name': 'Alice', 'age': 30, 'country': 'USA'}

# %%
#23.Write a code to access the value associated with the key "name" in the dictionary {'name':'John','age':30}
my_dict={'name':'John','age':30}
name_value=my_dict['name']
print(name_value)
# Out:
# John

# %%
#24.Write a code to remove the key "age" from the dictionary {'name':Bob, 'age':22, 'city':'New york'}
my_dictionary={'name':'Bob', 'age':22, 'city':'New york'}
del my_dictionary['age']
print(my_dictionary)
# Out:
# {'name': 'Bob', 'city': 'New york'}

# %%
#25.Write a code to check if the key "city" exists in the dictionary{'name':'Alice','city':'Paris'}
new_dict={'name':'Alice','city':'Paris'}
print("city" in new_dict)
# Out:
# True

# %%
#26.Write a code to create a list, a tuple, and a dictionary, and print them all.
my_list=[10,20,30]
my_tuple=(1,3,4)
my_dict={'name':'Alice','city':'Paris'}
print("My list:",my_list)
print("My tuple:", my_tuple)
print("My dict:", my_dict)
# Out:
# My list: [10, 20, 30]
# My tuple: (1, 3, 4)
# My dict: {'name': 'Alice', 'city': 'Paris'}

# %%
#27.Write a code to create a list of 5 random numbers between 1 and 100, sort in ascending order, and print the result.(replaced).
import random
random_num=[random.randint(1,100)for _ in range(5)]
random_num.sort()
print("Your sorted list of 5 random numbers:", random_num)
# Out:
# original_list [28, 48, 85, 91, 98]

# %%
#28.Write a code to create a list with strings and print the element at the third index.
my_things=["apples","bananas","pineapple","cherry"]
print(my_things[3])
# Out:
# cherry

# %%
#29.Write a code to combine two dictionaries into one and print the result.
dict1 = {"name": "Alice", "age": 30}
dict2 = {"city": "New York", "job": "Engineer"}
combined_dicts={**dict1,**dict2}
print (combined_dicts)
# Out:
# {'name': 'Alice', 'age': 30, 'city': 'New York', 'job': 'Engineer'}

# %%
#30.Write a code to convert a list of strings into a set.
string_list=["apples","bananas","pineapple","cherry"]
string_set=set(string_list)
print(string_set)
# Out:
# {'bananas', 'pineapple', 'apples', 'cherry'}

# %%
import math
print(dir(math))
# Out:
# ['__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'acos', 'acosh', 'asin', 'asinh', 'atan', 'atan2', 'atanh', 'cbrt', 'ceil', 'comb', 'copysign', 'cos', 'cosh', 'degrees', 'dist', 'e', 'erf', 'erfc', 'exp', 'exp2', 'expm1', 'fabs', 'factorial', 'floor', 'fma', 'fmod', 'frexp', 'fsum', 'gamma', 'gcd', 'hypot', 'inf', 'isclose', 'isfinite', 'isinf', 'isnan', 'isqrt', 'lcm', 'ldexp', 'lgamma', 'log', 'log10', 'log1p', 'log2', 'modf', 'nan', 'nextafter', 'perm', 'pi', 'pow', 'prod', 'radians', 'remainder', 'sin', 'sinh', 'sqrt', 'sumprod', 'tan', 'tanh', 'tau', 'trunc', 'ulp']
